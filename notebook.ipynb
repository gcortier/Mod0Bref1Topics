# %%
print("Hello")
a = 1
# Out:
# Hello

# %% [markdown]
# # Titre

# %%
a
# Out:
# 1

# %%
indices = [1,2,3]
valeurs = [4,3,6]
print (indices, valeurs)
# Out:
# [1, 2, 3] [4, 3, 6]

# %%
from matplotlib import pyplot as plt
plt.plot(indices, valeurs, "o-r", lw=2, label="line")
plt.grid()
plt.legend()
plt.title('ma ligne')
# Out:
# Text(0.5, 1.0, 'ma ligne')

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
sentiment = sia.polarity_scores("i'm sad")
print(sentiment)
# Out:
# {'neg': 0.756, 'neu': 0.244, 'pos': 0.0, 'compound': -0.4767}
